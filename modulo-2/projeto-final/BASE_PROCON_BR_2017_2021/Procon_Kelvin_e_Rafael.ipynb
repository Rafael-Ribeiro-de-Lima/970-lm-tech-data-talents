# %% [markdown]
# # Análise descritiva base de dados PROCON BR

# %% [markdown]
# O objetivo deste relátorio é treinar o desenvolvimento de queries em POSTGRESQL bem como praticar alguns conceitos de normalização e correção de dados em tabelas. Para isso será realizada uma análise descritiva dos dados contidos nas bases do
# Sistema Nacional de Informações de Defesa do Consumidor (SINDEC- Procons), disponível em:
# https://dados.mj.gov.br/dataset/cadastro-nacional-de-reclamacoes-fundamentadas-procons-sindec
#
# Essa base de dados consiste de Reclamações fundamentadas dos consumidores que não conseguiram
# resolver seus problemas por caminhos mais simples,e então necessitam realizar uma audiência para tentativa
# de resolução, o que pode acontecer tanto pela complexidade da demanda, quanto pelo tipo de postura
# adotado pelo fornecedor na resolução do conflito.
#
# Para concluir o objetivo deste relatório, primeiramente é necessario realizar a consolidação dos dados,
# uma vez que eles são disponibilizados em arquivos anuais. Foi determinado que os dados a serem analisados correspondem
# ao periodo entre os anos de 2017 e 2021.
# Posteriormente será feita uma avaliação com o intuito de identificar possíveis normalizações ou otimizações a serem feitas nas
# tabelas. Finalmente as tabelas organizadas serão copiadas para um banco POSTGRESQL aonde serão feitas as queries
# para investigarmos os dados.
#
# Trabalho desenvolvido durante o curso LM Tech Data Talents - ministrado pela escola ADA em parceria com a Leroy Merlin por :
#
# Rafael Ribeiro Lima - https://www.linkedin.com/in/rafael-ribeiro-de-lima/
#
# Kelvin Pichinini - https://www.linkedin.com/in/kelvinpichinini/

# %% [markdown]
# ### CONSOLIDANDO OS ARQUIVOS ANUAIS

# %%
import csv
with open('cnrf2021.csv','r',encoding="utf-8-sig") as file:
    base_consolidada = list(csv.reader(file, delimiter=';'))
    for year in range(2017,2021):            
        with open(f'CNRF{year}.csv','r',encoding="utf-8-sig") as file:
            base = list(csv.reader(file, delimiter=';'))
            if(base[0] == base_consolidada[0]):
                base = base[1:]
            base_consolidada += base
    with open('base_consolidada.csv','w',encoding="utf-8-sig") as final_file:
        writer = csv.writer(final_file, delimiter=';', lineterminator='\n')
        writer.writerows(base_consolidada)

# %% [markdown]
# ### VERIFICANDO ESTRUTURA DOS DADOS E POSSIVEIS NORMALIZAÇÕES

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('base_consolidada.csv',
                 sep=";",
                 encoding="utf-8-sig",
                 on_bad_lines='skip',
                 parse_dates = ['DataArquivamento','DataAbertura'],
                 dtype = {
                     'NumeroCNPJ':str,
                     'RadicalCNPJ':str,
                     'CNAEPrincipal':str,
                     'CodigoAssunto':str,
                     'CodigoProblema':str,
                 })
df.head()
# Out:
#    AnoCalendario    DataArquivamento        DataAbertura  CodigoRegiao Regiao  \
# 0           2021 2021-03-03 10:19:00 2021-01-19 12:00:34             1  Norte
# 1           2021 2021-04-07 10:55:17 2021-02-19 09:33:43             1  Norte
# 2           2021 2021-03-31 09:29:57 2021-02-22 10:48:12             1  Norte
# 3           2021 2021-08-03 10:42:54 2021-06-16 11:10:37             1  Norte
# 4           2021 2021-09-21 09:22:33 2021-07-16 12:38:52             1  Norte
#
#    UF                                 strRazaoSocial         strNomeFantasia  \
# 0  PA  MULTIMARCAS ADMINISTRADORA DE CONSÓRCIOS LTDA  MULTIMARCAS CONSÓRCIOS
# 1  PA                           A SARAIVA SOUZA - ME           MERITO CURSOS
# 2  PA             AZUL LINHAS AÉREAS BRASILEIRAS S.A      AZUL LINHAS AÉREAS
# 3  PA             AZUL LINHAS AÉREAS BRASILEIRAS S.A      AZUL LINHAS AÉREAS
# 4  PA                       MOTOROLA INDUSTRIAL LTDA                MOTOROLA
#
#    Tipo      NumeroCNPJ  ... CNAEPrincipal  \
# 0     1   4124922000161  ...       6493000
# 1     1  21364925000191  ...           NaN
# 2     1   9296295000160  ...       5111100
# 3     1   9296295000160  ...       5111100
# 4     1   1472720000112  ...       4652400
#
#                                    DescCNAEPrincipal Atendida CodigoAssunto  \
# 0  ADMINISTRAÇÃO DE CONSÓRCIOS PARA AQUISIÇÃO DE ...        N            57
# 1                                                NaN        N           236
# 2            TRANSPORTE AÉREO DE PASSAGEIROS REGULAR        N           276
# 3            TRANSPORTE AÉREO DE PASSAGEIROS REGULAR        N           276
# 4  COMÉRCIO ATACADISTA DE COMPONENTES ELETRÔNICOS...        N           101
#
#                                     DescricaoAssunto CodigoProblema  \
# 0  Consórcio de Automóveis ou Automotores, Utilit...           1307
# 1                               Cursos Livres Outros           5369
# 2  Agências e Operadoras de viagens (pacotes turí...           5157
# 3  Agências e Operadoras de viagens (pacotes turí...           5760
# 4  Telefone ( Convencional, Celular, Interfone, E...            NaN
#
#                           DescricaoProblema SexoConsumidor  \
# 0                  Desistência de consorcio              M
# 1                 Cobrança indevida/abusiva              F
# 2   Recusa injustificada em prestar serviço              F
# 3  Contrato - Rescisão/alteração unilateral              F
# 4                                       NaN              F
#
#   FaixaEtariaConsumidor CEPConsumidor
# 0    entre 21 a 30 anos    68000001.0
# 1    entre 31 a 40 anos    68143000.0
# 2    entre 31 a 40 anos    68040020.0
# 3    entre 21 a 30 anos    68020620.0
# 4    entre 31 a 40 anos           NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# A base fornecida possui 22 colunas e abaixo segue um resumo do que cada uma representa:
#
#     -Data/Período em que reclamação foi aberta e arquivada:
#         "AnoCalendario", "DataArquivamento" e "DataAbertura"
#     -Localização da ocorrência:
#         "CodigoRegiao", "Regiao" e "UF"
#     -Dados do fornecedor:
#         "strRazaoSocial", "strNomeFantasia","Tipo", "NúmeroCNPJ","RadicalCNPJ", "CNAEPrincipal","DescCNAEPrincipal"
#     -Informações sobre o problema ou reclamação:
#         "Atendida", "CodigoAssunto", "DescricaoAssunto", "CodigoProblema", "DescricaoProblema"
#     -Informações sobre o consumidor:
#         "Sexo", "FaixaEtariaConsumidor", "CEPConsumidor"
#
# Analisando essa estrutura é possível verificar que não existem colunas com entradas multivaloradas, portanto nenhuma correção
# precisa ser feita neste ponto. No entanto, existem colunas em que os valores se repetem muitas vezes e podem ser separados
# em outras tabelas. Todas as colunas classificadas acima como "DADOS DO FORNECEDOR" serão substituidas por uma única coluna
# chamada de  "CodigoFornecedor", as informações dessas colunas serão armazenadas em outra tabela onde não haverá duplicidade
# de registros. Outras duas tabelas também serão criadas para eliminar a duplicidade de registros na tabela principal de reclamações,
# serão as tabelas "Assuntos" e "Problemas".

# %% [markdown]
# As colunas "CodigoRegiao", "Tipo" e "CEPConsumidor" apresentam dados que não serão utilizados em nossa analise e por isso serão removidas.

# %%
df.drop(columns=["CodigoRegiao", "Tipo", "CEPConsumidor"], inplace=True)

# %% [markdown]
# ### Limpando as tabelas

# %% [markdown]
# Verificando valores nulos ou faltantes

# %%
df.isnull().sum()
# Out:
# AnoCalendario                0
# DataArquivamento            25
# DataAbertura                12
# Regiao                       0
# UF                           0
# strRazaoSocial               3
# strNomeFantasia          20121
# NumeroCNPJ                6259
# RadicalCNPJ               6496
# RazaoSocialRFB           15608
# NomeFantasiaRFB          66741
# CNAEPrincipal            15608
# DescCNAEPrincipal        16172
# Atendida                     0
# CodigoAssunto               14
# DescricaoAssunto            14
# CodigoProblema           65440
# DescricaoProblema        65440
# SexoConsumidor              37
# FaixaEtariaConsumidor        0
# dtype: int64

# %% [markdown]
# #### Corrigindo strNomeFantasia nulo
#
# A solução escolhida aqui foi copiar o valor do campo strRazaoSocial para o campo strNomeFantasia nas linhas que não possuirem um nome fantasia cadastrado

# %%
df['strNomeFantasia'].fillna(df['strRazaoSocial'], inplace=True)
df[df['strNomeFantasia'].isnull()]
# Out:
#        AnoCalendario    DataArquivamento        DataAbertura    Regiao  UF  \
# 9973            2017 2018-05-03 14:03:57 2018-03-16 10:35:54  Nordeste  RN
# 54758           2018 2018-11-28 11:41:57 2018-10-22 12:22:11  Nordeste  RN
# 65886           2018 2018-05-03 14:03:57 2018-03-16 10:35:54  Nordeste  RN
#
#       strRazaoSocial strNomeFantasia NumeroCNPJ RadicalCNPJ RazaoSocialRFB  \
# 9973             NaN             NaN        NaN         NaN            NaN
# 54758            NaN             NaN        NaN         NaN            NaN
# 65886            NaN             NaN        NaN         NaN            NaN
#
#       NomeFantasiaRFB CNAEPrincipal DescCNAEPrincipal Atendida CodigoAssunto  \
# 9973              NaN           NaN               NaN        N           145
# 54758             NaN           NaN               NaN        S           120
# 65886             NaN           NaN               NaN        N           145
#
#           DescricaoAssunto CodigoProblema DescricaoProblema SexoConsumidor  \
# 9973                 Motos            NaN               NaN              M
# 54758  Móveis Para Cozinha            NaN               NaN              F
# 65886                Motos            NaN               NaN              M
#
#       FaixaEtariaConsumidor
# 9973     entre 21 a 30 anos
# 54758    entre 41 a 50 anos
# 65886    entre 21 a 30 anos

# %% [markdown]
# Esstes 3 casos que sobraram estão muito mal registrados, não possuem informação nenhum sobre a empresa ou sobre o problema, e, por isso serão excluidos

# %%
df.dropna(how='any', inplace=True, subset= "strRazaoSocial")

# %% [markdown]
# #### Corrigindo nº de CNPJ vazio

# %% [markdown]
# Copiando os NumeroCNPJ e RadicalCNPJ de outros registros que tenham exatamente o mesmo valor de strRazaoSocial

# %%
s = df.groupby("strRazaoSocial")["NumeroCNPJ"].transform(lambda x: next(iter(x.mode()), np.nan))
df['NumeroCNPJ'] = df['NumeroCNPJ'].fillna(s)

s = df.groupby("strRazaoSocial")["RadicalCNPJ"].transform(lambda x: next(iter(x.mode()), np.nan))
df['RadicalCNPJ'] = df['RadicalCNPJ'].fillna(s)

# %% [markdown]
# Copiando os NumeroCNPJ e RadicalCNPJ de outros registros que tenham exatamente o mesmo valor de strNomeFantasia

# %%
s = df.groupby("strNomeFantasia")["NumeroCNPJ"].transform(lambda x: next(iter(x.mode()), np.nan))
df['NumeroCNPJ'] = df['NumeroCNPJ'].fillna(s)

s = df.groupby("strNomeFantasia")["RadicalCNPJ"].transform(lambda x: next(iter(x.mode()), np.nan))
df['RadicalCNPJ'] = df['RadicalCNPJ'].fillna(s)

# %%
df['NumeroCNPJ'].isnull().sum()
# Out:
# 3606

# %% [markdown]
# Restaram 3606 registros onde não foi possível identificar um número de cnpj.

# %% [markdown]
# #### Corrigindo CNAEPrincipal e DescCNAEPrincipal vazios
# Copiando os CNAEPrincial e DescCNAEPrincipal de outros registros que tenham exatamente o mesmo valor de NumeroCNPJ

# %%
s = df.groupby("NumeroCNPJ")["CNAEPrincipal"].transform(lambda x: next(iter(x.mode()), np.nan))
df['CNAEPrincipal'] = df['CNAEPrincipal'].fillna(s)

s = df.groupby("NumeroCNPJ")["DescCNAEPrincipal"].transform(lambda x: next(iter(x.mode()), np.nan))
df['DescCNAEPrincipal'] = df['DescCNAEPrincipal'].fillna(s)

# %%
df['CNAEPrincipal'].isnull().sum()
# Out:
# 13698

# %%
(df['CNAEPrincipal'].isnull() & df['NumeroCNPJ'].notnull()).sum()
# Out:
# 10118

# %% [markdown]
# Restaram 13698 registros sem informação do CNAE da empresa, destes 10118 possuem um número de CNPJ cadastrado. Para trabalhos futuros recomenda-se alguma técnica de webscrapping ou consultas de api's para encontrar o CNAE de cada empresa buscando pelo seu CNPJ.

# %% [markdown]
# #### CodigoAssunto nulo ou vazio
#
# Analisando as 14 entradas abaixo não foi possivel identificar o motivo de não ter sido cadastrado um codigo de assunto. Uma hipotese seria por ser um assunto ainda não categorizado uma vez que o campo DescricaoProblema de todos estes está como "Não se aplica" ou  por ser uma reclamação infudamentada.

# %%
df[df['CodigoAssunto'].isnull()]
# Out:
#         AnoCalendario    DataArquivamento        DataAbertura   Regiao  UF  \
# 90849            2019 2019-09-30 10:27:21 2019-04-24 23:00:16  Sudeste  SP
# 91270            2019 2019-09-30 09:40:21 2019-04-11 23:00:24  Sudeste  SP
# 92022            2019 2019-09-30 09:47:49 2019-04-16 23:00:12  Sudeste  SP
# 95169            2019 2019-09-30 09:38:06 2019-04-04 23:00:13  Sudeste  SP
# 95429            2019 2019-09-30 10:48:13 2019-04-30 23:00:23  Sudeste  SP
# 96287            2019 2019-09-26 16:12:14 2019-04-25 23:00:16  Sudeste  SP
# 97280            2019 2019-09-30 09:47:49 2019-04-18 23:00:13  Sudeste  SP
# 97547            2019 2019-09-30 10:25:43 2019-05-17 23:00:25  Sudeste  SP
# 99188            2019 2019-09-30 10:30:43 2019-04-26 23:00:15  Sudeste  SP
# 99189            2019 2019-09-30 09:44:36 2019-04-15 23:00:13  Sudeste  SP
# 103106           2019 2019-09-30 09:38:06 2019-04-04 23:00:13  Sudeste  SP
# 103384           2019 2019-09-30 10:25:43 2019-05-27 23:00:08  Sudeste  SP
# 106238           2019 2019-09-30 10:27:21 2019-05-23 23:00:21  Sudeste  SP
# 106429           2019 2019-09-30 09:47:49 2019-04-01 23:00:16  Sudeste  SP
#
#                                strRazaoSocial  \
# 90849        SKY SERVIÇOS DE BANDA LARGA LTDA
# 91270                               CLARO S/A
# 92022                               CLARO S/A
# 95169                               CLARO S/A
# 95429                               CLARO S/A
# 96287                SKY BRASIL SERVIÇOS LTDA
# 97280   GETNINJAS ATIVIDADES DE INTERNET LTDA
# 97547                               CLARO S/A
# 99188        SKY SERVIÇOS DE BANDA LARGA LTDA
# 99189                   TELEFONICA BRASIL S/A
# 103106                              CLARO S/A
# 103384       SKY SERVIÇOS DE BANDA LARGA LTDA
# 106238                              CLARO S/A
# 106429                UNIVERSO ONLINE S/A UOL
#
#                                  strNomeFantasia      NumeroCNPJ RadicalCNPJ  \
# 90849                                        SKY    497373000110    00497373
# 91270           CLARO / NET / EMBRATEL / CLAROTV  40432544000147    40432544
# 92022           CLARO / NET / EMBRATEL / CLAROTV  40432544000147    40432544
# 95169           CLARO / NET / EMBRATEL / CLAROTV  40432544000147    40432544
# 95429           CLARO / NET / EMBRATEL / CLAROTV  40432544000147    40432544
# 96287                                        SKY  72820822000120    72820822
# 97280                           GETNINJAS.COM.BR  14127813000151    14127813
# 97547           CLARO / NET / EMBRATEL / CLAROTV  40432544000147    40432544
# 99188                                        SKY    497373000110    00497373
# 99189                            VIVO/TELEFÔNICA   2558157000162    02558157
# 103106          CLARO / NET / EMBRATEL / CLAROTV  40432544000147    40432544
# 103384                                       SKY    497373000110    00497373
# 106238          CLARO / NET / EMBRATEL / CLAROTV  40432544000147    40432544
# 106429  EMPREGOCERTO/TODAOFERTA/TODODESCONTO/BOA   1109184000195    01109184
#
#                                 RazaoSocialRFB NomeFantasiaRFB CNAEPrincipal  \
# 90849                      GALAXY BRASIL LTDA.         DIRECTV       6143400
# 91270                               CLARO S.A.           CLARO       6120501
# 92022                               CLARO S.A.           CLARO       6120501
# 95169                               CLARO S.A.           CLARO       6120501
# 95429                               CLARO S.A.           CLARO       6120501
# 96287                 SKY BRASIL SERVICOS LTDA             SKY       6143400
# 97280   GETNINJAS ATIVIDADES DE INTERNET LTDA.             NaN       6319400
# 97547                               CLARO S.A.           CLARO       6120501
# 99188                      GALAXY BRASIL LTDA.         DIRECTV       6143400
# 99189                   TELEFONICA BRASIL S.A.             NaN       6110801
# 103106                              CLARO S.A.           CLARO       6120501
# 103384                     GALAXY BRASIL LTDA.         DIRECTV       6143400
# 106238                              CLARO S.A.           CLARO       6120501
# 106429                     UNIVERSO ONLINE S/A             NaN       6319400
#
#                                         DescCNAEPrincipal Atendida  \
# 90849   OPERADORAS DE TELEVISÃO POR ASSINATURA POR SAT...        S
# 91270                             TELEFONIA MÓVEL CELULAR        S
# 92022                             TELEFONIA MÓVEL CELULAR        N
# 95169                             TELEFONIA MÓVEL CELULAR        S
# 95429                             TELEFONIA MÓVEL CELULAR        N
# 96287   OPERADORAS DE TELEVISÃO POR ASSINATURA POR SAT...        N
# 97280   PORTAIS, PROVEDORES DE CONTEÚDO E OUTROS SERVI...        N
# 97547                             TELEFONIA MÓVEL CELULAR        N
# 99188   OPERADORAS DE TELEVISÃO POR ASSINATURA POR SAT...        S
# 99189          SERVIÇOS DE TELEFONIA FIXA COMUTADA - STFC        N
# 103106                            TELEFONIA MÓVEL CELULAR        N
# 103384  OPERADORAS DE TELEVISÃO POR ASSINATURA POR SAT...        S
# 106238                            TELEFONIA MÓVEL CELULAR        S
# 106429  PORTAIS, PROVEDORES DE CONTEÚDO E OUTROS SERVI...        S
#
#        CodigoAssunto DescricaoAssunto CodigoProblema DescricaoProblema  \
# 90849            NaN              NaN              0     Não se aplica
# 91270            NaN              NaN              0     Não se aplica
# 92022            NaN              NaN              0     Não se aplica
# 95169            NaN              NaN              0     Não se aplica
# 95429            NaN              NaN              0     Não se aplica
# 96287            NaN              NaN              0     Não se aplica
# 97280            NaN              NaN              0     Não se aplica
# 97547            NaN              NaN              0     Não se aplica
# 99188            NaN              NaN              0     Não se aplica
# 99189            NaN              NaN              0     Não se aplica
# 103106           NaN              NaN              0     Não se aplica
# 103384           NaN              NaN              0     Não se aplica
# 106238           NaN              NaN              0     Não se aplica
# 106429           NaN              NaN              0     Não se aplica
#
#        SexoConsumidor FaixaEtariaConsumidor
# 90849               F    entre 51 a 60 anos
# 91270               F    entre 21 a 30 anos
# 92022               M    entre 41 a 50 anos
# 95169               F    entre 31 a 40 anos
# 95429               M    entre 61 a 70 anos
# 96287               F    entre 31 a 40 anos
# 97280               M    entre 31 a 40 anos
# 97547               M    entre 61 a 70 anos
# 99188               F    entre 31 a 40 anos
# 99189               F    entre 21 a 30 anos
# 103106              M    entre 41 a 50 anos
# 103384              F    entre 21 a 30 anos
# 106238              M    entre 21 a 30 anos
# 106429              F    entre 51 a 60 anos

# %% [markdown]
# #### CodigoProblema nulo ou vazio

# %%
(df['CodigoProblema'].isnull() & df['DescricaoProblema'].isnull()).sum()
# Out:
# 65437

# %% [markdown]
# dos 65.440 valores vazios para codigo do problema 65437 também não possuem uma descrição para o problema, dessa forma fica impossível fazer qualquer correção sem informações adicionais.

# %% [markdown]
# #### Completando numeros de cnpj com 0's no começo da string

# %%
df["NumeroCNPJ"] = df["NumeroCNPJ"].apply(lambda x: str(x).zfill(14))
df.head(2)
# Out:
#    AnoCalendario    DataArquivamento        DataAbertura Regiao  UF  \
# 0           2021 2021-03-03 10:19:00 2021-01-19 12:00:34  Norte  PA
# 1           2021 2021-04-07 10:55:17 2021-02-19 09:33:43  Norte  PA
#
#                                   strRazaoSocial         strNomeFantasia  \
# 0  MULTIMARCAS ADMINISTRADORA DE CONSÓRCIOS LTDA  MULTIMARCAS CONSÓRCIOS
# 1                           A SARAIVA SOUZA - ME           MERITO CURSOS
#
#        NumeroCNPJ RadicalCNPJ                                 RazaoSocialRFB  \
# 0  04124922000161    04124922  MULTIMARCAS ADMINISTRADORA DE CONSORCIOS LTDA
# 1  21364925000191    21364925                                            NaN
#
#           NomeFantasiaRFB CNAEPrincipal  \
# 0  MULTIMARCAS CONSORCIOS       6493000
# 1                     NaN           NaN
#
#                                    DescCNAEPrincipal Atendida CodigoAssunto  \
# 0  ADMINISTRAÇÃO DE CONSÓRCIOS PARA AQUISIÇÃO DE ...        N            57
# 1                                                NaN        N           236
#
#                                     DescricaoAssunto CodigoProblema  \
# 0  Consórcio de Automóveis ou Automotores, Utilit...           1307
# 1                               Cursos Livres Outros           5369
#
#            DescricaoProblema SexoConsumidor FaixaEtariaConsumidor
# 0   Desistência de consorcio              M    entre 21 a 30 anos
# 1  Cobrança indevida/abusiva              F    entre 31 a 40 anos

# %%
df.isnull().sum()
# Out:
# AnoCalendario                0
# DataArquivamento            25
# DataAbertura                12
# Regiao                       0
# UF                           0
# strRazaoSocial               0
# strNomeFantasia              0
# NumeroCNPJ                   0
# RadicalCNPJ               3815
# RazaoSocialRFB           15605
# NomeFantasiaRFB          66738
# CNAEPrincipal            13698
# DescCNAEPrincipal        14275
# Atendida                     0
# CodigoAssunto               14
# DescricaoAssunto            14
# CodigoProblema           65437
# DescricaoProblema        65437
# SexoConsumidor              37
# FaixaEtariaConsumidor        0
# dtype: int64

# %% [markdown]
# ### EMANCIPANDO TABELA FORNECEDORES

# %%
# Copiando valores para nova tabela
fornecedores = df[["strRazaoSocial", "strNomeFantasia", "NumeroCNPJ","RadicalCNPJ","CNAEPrincipal","DescCNAEPrincipal","RazaoSocialRFB","NomeFantasiaRFB"]].copy()
#Removendo valores duplicados
fornecedores.drop_duplicates(subset=['NumeroCNPJ'], inplace=True)
#Adicionando um codigo unico para cada fornecedor
fornecedores['CodigoFornecedor'] = range(1, len(fornecedores) + 1)
#Adicionando cod de fornecedor na tabela principal
df = df.merge(fornecedores[["NumeroCNPJ", "CodigoFornecedor"]], on = 'NumeroCNPJ', how = "left")
#Excluindo colunas com infos do fonercedor na tabela principal
df.drop(columns=["strRazaoSocial", "strNomeFantasia", "NumeroCNPJ","RadicalCNPJ","CNAEPrincipal","DescCNAEPrincipal","RazaoSocialRFB","NomeFantasiaRFB"], inplace=True)

# %% [markdown]
# ### EMANCIPANDO TABELA ASSUNTOS

# %%
# Copiando valores para nova tabela
assuntos = df[["CodigoAssunto", "DescricaoAssunto"]].copy()
#Removendo valores duplicados
assuntos.drop_duplicates(subset=['CodigoAssunto'], inplace=True)
#Excluindo coluna descrição assunto na tabela principal
df.drop(columns=['DescricaoAssunto'], inplace=True)

# %% [markdown]
# ### EMANCIPANDO TABELA PROBLEMAS

# %%
# Copiando valores para nova tabela
problemas = df[["CodigoProblema", "DescricaoProblema"]].copy()
#Removendo valores duplicados
problemas.drop_duplicates(subset=['CodigoProblema'], inplace=True)
#Excluindo coluna descrição assunto na tabela principal
df.drop(columns=['DescricaoProblema'], inplace=True)

# %% [markdown]
# ### RESULTADO TABELAS

# %%
df.head(2)
# Out:
#    AnoCalendario    DataArquivamento        DataAbertura Regiao  UF Atendida  \
# 0           2021 2021-03-03 10:19:00 2021-01-19 12:00:34  Norte  PA        N
# 1           2021 2021-04-07 10:55:17 2021-02-19 09:33:43  Norte  PA        N
#
#   CodigoAssunto CodigoProblema SexoConsumidor FaixaEtariaConsumidor  \
# 0            57           1307              M    entre 21 a 30 anos
# 1           236           5369              F    entre 31 a 40 anos
#
#    CodigoFornecedor
# 0                 1
# 1                 2

# %%
fornecedores.head(1)
# Out:
#                                   strRazaoSocial         strNomeFantasia  \
# 0  MULTIMARCAS ADMINISTRADORA DE CONSÓRCIOS LTDA  MULTIMARCAS CONSÓRCIOS
#
#        NumeroCNPJ RadicalCNPJ CNAEPrincipal  \
# 0  04124922000161    04124922       6493000
#
#                                    DescCNAEPrincipal  \
# 0  ADMINISTRAÇÃO DE CONSÓRCIOS PARA AQUISIÇÃO DE ...
#
#                                   RazaoSocialRFB         NomeFantasiaRFB  \
# 0  MULTIMARCAS ADMINISTRADORA DE CONSORCIOS LTDA  MULTIMARCAS CONSORCIOS
#
#    CodigoFornecedor
# 0                 1

# %%
problemas.head(2)
# Out:
#   CodigoProblema          DescricaoProblema
# 0           1307   Desistência de consorcio
# 1           5369  Cobrança indevida/abusiva

# %%
assuntos.head(2)
# Out:
#   CodigoAssunto                                   DescricaoAssunto
# 0            57  Consórcio de Automóveis ou Automotores, Utilit...
# 1           236                               Cursos Livres Outros

# %% [markdown]
# ### CRIANDO OS BANCOS POSTGRESQL

# %%
from sqlalchemy import create_engine
import pandas as pd 

engine = create_engine('postgresql+psycopg2://postgres:kelvin@localhost/postgres')
with engine.connect() as conn:
    conn.execute('''DROP TABLE IF EXISTS reclamacoes; ''')
    conn.execute('''DROP TABLE IF EXISTS fornecedores; ''')
    conn.execute('''DROP TABLE IF EXISTS assuntos; ''')
    conn.execute('''DROP TABLE IF EXISTS problemas; ''')
    df.to_sql('reclamacoes', engine, index = False)
    fornecedores.to_sql('fornecedores', engine, index = False)
    assuntos.to_sql('assuntos', engine, index = False)
    problemas.to_sql('problemas', engine, index = False)
engine.dispose()

# %% [markdown]
# ### Salvando tabelas em csv

# %%
df.to_csv('reclamacoes.csv', sep=';', encoding='"utf-8-sig"')
fornecedores.to_csv('fornecedores.csv', sep=';', encoding='"utf-8-sig"')
assuntos.to_csv('assuntos.csv', sep=';', encoding='"utf-8-sig"')
problemas.to_csv('problemas.csv', sep=';', encoding='"utf-8-sig"')

# %% [markdown]
# ### Fazendo as queries - Tabela Fornecedores

# %%
from sqlalchemy import text
with engine.connect() as conn:
    # Query quantidade de registros
    query = text('''SELECT COUNT(*) FROM fornecedores;''')
    df = pd.read_sql_query(query, con = conn)
    print(f'Contagem de registros:', df.values[0])
    
    # Query nomes colunas e tipos
    query = text('''SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'fornecedores';''')
    df = pd.read_sql_query(query, con = conn)
    print('\nNOME DAS COLUNAS E TIPOS :')
    print(df)
    
    # Primeiro 5 registros
    query = text('''SELECT * FROM fornecedores LIMIT 5''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
# Out:
# Contagem de registros: [18397]
#
# NOME DAS COLUNAS E TIPOS :
#          column_name data_type
# 0   CodigoFornecedor    bigint
# 1    strNomeFantasia      text
# 2         NumeroCNPJ      text
# 3        RadicalCNPJ      text
# 4     strRazaoSocial      text
# 5  DescCNAEPrincipal      text
# 6     RazaoSocialRFB      text
# 7    NomeFantasiaRFB      text
# 8      CNAEPrincipal      text

# %% [markdown]
# Primeiros 5 registros:

# %%
df.head()
# Out:
#                                   strRazaoSocial         strNomeFantasia  \
# 0  MULTIMARCAS ADMINISTRADORA DE CONSÓRCIOS LTDA  MULTIMARCAS CONSÓRCIOS
# 1                           A SARAIVA SOUZA - ME           MERITO CURSOS
# 2             AZUL LINHAS AÉREAS BRASILEIRAS S.A      AZUL LINHAS AÉREAS
# 3                       MOTOROLA INDUSTRIAL LTDA                MOTOROLA
# 4                       MM TURISMO E VIAGENS S.A               MAXMILHAS
#
#        NumeroCNPJ RadicalCNPJ CNAEPrincipal  \
# 0  04124922000161    04124922       6493000
# 1  21364925000191    21364925          None
# 2  09296295000160    09296295       5111100
# 3  01472720000112    01472720       4652400
# 4  16988607000161    16988607       7490104
#
#                                    DescCNAEPrincipal  \
# 0  ADMINISTRAÇÃO DE CONSÓRCIOS PARA AQUISIÇÃO DE ...
# 1                                               None
# 2            TRANSPORTE AÉREO DE PASSAGEIROS REGULAR
# 3  COMÉRCIO ATACADISTA DE COMPONENTES ELETRÔNICOS...
# 4  ATIVIDADES DE INTERMEDIAÇÃO E AGENCIAMENTO DE ...
#
#                                       RazaoSocialRFB         NomeFantasiaRFB  \
# 0      MULTIMARCAS ADMINISTRADORA DE CONSORCIOS LTDA  MULTIMARCAS CONSORCIOS
# 1                                               None                    None
# 2                AZUL LINHAS AEREAS BRASILEIRAS S.A.                    None
# 3  MOTOROLA MOBILITY COMERCIO DE PRODUTOS ELETRON...                    None
# 4                               MAX MILHAS LTDA - ME              MAX MILHAS
#
#    CodigoFornecedor
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5

# %% [markdown]
# ### Fazendo as queries - Tabela Assuntos

# %%
with engine.connect() as conn:
    # Query quantidade de registros
    query = text('''SELECT COUNT(*) FROM assuntos;''')
    df = pd.read_sql_query(query, con = conn)
    print(f'Contagem de registros:', df.values[0])
    
    # Query nomes colunas e tipos
    query = text('''SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'assuntos';''')
    df = pd.read_sql_query(query, con = conn)
    print('\nNOME DAS COLUNAS E TIPOS :')
    print(df)
    
    # Primeiro 5 registros
    query = text('''SELECT * FROM assuntos LIMIT 5''')
    df = pd.read_sql_query(query, con = conn)
    print('\nPrimeiros 5 registros :')
    print(df)
engine.dispose()
# Out:
# Contagem de registros: [224]
#
# NOME DAS COLUNAS E TIPOS :
#         column_name data_type
# 0     CodigoAssunto      text
# 1  DescricaoAssunto      text
#
# Primeiros 5 registros :
#   CodigoAssunto                                   DescricaoAssunto
# 0            57  Consórcio de Automóveis ou Automotores, Utilit...
# 1           236                               Cursos Livres Outros
# 2           276  Agências e Operadoras de viagens (pacotes turí...
# 3           101  Telefone ( Convencional, Celular, Interfone, E...
# 4           156                Transporte  ( Passageiros, Cargas )

# %% [markdown]
# ### Fazendo as queries - Tabela Problemas

# %%
with engine.connect() as conn:
    # Query quantidade de registros
    query = text('''SELECT COUNT(*) FROM problemas;''')
    df = pd.read_sql_query(query, con = conn)
    print(f'Contagem de registros:', df.values[0])
    
    # Query nomes colunas e tipos
    query = text('''SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'problemas';''')
    df = pd.read_sql_query(query, con = conn)
    print('\nNOME DAS COLUNAS E TIPOS :')
    print(df)
    
    # Primeiro 4 registros
    query = text('''SELECT * FROM problemas LIMIT 4''')
    df = pd.read_sql_query(query, con = conn)
    print('\nPrimeiros 4 registros :')
    print(df)
engine.dispose()
# Out:
# Contagem de registros: [2569]
#
# NOME DAS COLUNAS E TIPOS :
#          column_name data_type
# 0     CodigoProblema      text
# 1  DescricaoProblema      text
#
# Primeiros 4 registros :
#   CodigoProblema                         DescricaoProblema
# 0           1307                  Desistência de consorcio
# 1           5369                 Cobrança indevida/abusiva
# 2           5157   Recusa injustificada em prestar serviço
# 3           5760  Contrato - Rescisão/alteração unilateral

# %% [markdown]
# ### Fazendo as queries - Tabela Reclamações

# %%
with engine.connect() as conn:
    # Query quantidade de registros
    query = text('''SELECT COUNT(*) FROM reclamacoes;''')
    df = pd.read_sql_query(query, con = conn)
    print(f'Contagem de registros:', df.values[0])
    
    # Query nomes colunas e tipos
    query = text('''SELECT column_name, data_type FROM information_schema.columns WHERE table_name = 'reclamacoes';''')
    df = pd.read_sql_query(query, con = conn)
    print('\nNOME DAS COLUNAS E TIPOS :')
    print(df)
    
    # Primeiro 4 registros
    query = text('''SELECT * FROM reclamacoes LIMIT 4''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
# Out:
# Contagem de registros: [115919]
#
# NOME DAS COLUNAS E TIPOS :
#               column_name                    data_type
# 0           AnoCalendario                       bigint
# 1        DataArquivamento  timestamp without time zone
# 2            DataAbertura  timestamp without time zone
# 3        CodigoFornecedor                       bigint
# 4                      UF                         text
# 5                Atendida                         text
# 6           CodigoAssunto                         text
# 7          CodigoProblema                         text
# 8          SexoConsumidor                         text
# 9   FaixaEtariaConsumidor                         text
# 10                 Regiao                         text

# %% [markdown]
# Primeiros 4 registros:

# %%
df.head(4)
# Out:
#    AnoCalendario    DataArquivamento        DataAbertura Regiao  UF Atendida  \
# 0           2021 2021-03-03 10:19:00 2021-01-19 12:00:34  Norte  PA        N
# 1           2021 2021-04-07 10:55:17 2021-02-19 09:33:43  Norte  PA        N
# 2           2021 2021-03-31 09:29:57 2021-02-22 10:48:12  Norte  PA        N
# 3           2021 2021-08-03 10:42:54 2021-06-16 11:10:37  Norte  PA        N
#
#   CodigoAssunto CodigoProblema SexoConsumidor FaixaEtariaConsumidor  \
# 0            57           1307              M    entre 21 a 30 anos
# 1           236           5369              F    entre 31 a 40 anos
# 2           276           5157              F    entre 31 a 40 anos
# 3           276           5760              F    entre 21 a 30 anos
#
#    CodigoFornecedor
# 0                 1
# 1                 2
# 2                 3
# 3                 3

# %% [markdown]
# #### Reclamacoes por faixa etária:

# %%
with engine.connect() as conn:
    query = text('''SELECT "FaixaEtariaConsumidor", COUNT(*),ROUND((COUNT(*) / (SUM(COUNT(*)) OVER() )) * 100) as percentual 
                    FROM reclamacoes
                    GROUP BY "FaixaEtariaConsumidor"
                    ORDER BY "FaixaEtariaConsumidor" DESC;''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head(20)
# Out:
#   FaixaEtariaConsumidor  count  percentual
# 0         Nao Informada   9993         9.0
# 1       mais de 70 anos   6754         6.0
# 2    entre 61 a 70 anos  14472        12.0
# 3    entre 51 a 60 anos  17774        15.0
# 4    entre 41 a 50 anos  20947        18.0
# 5    entre 31 a 40 anos  25296        22.0
# 6    entre 21 a 30 anos  18343        16.0
# 7           até 20 anos   2340         2.0

# %% [markdown]
# #### Genero dos reclamantes

# %%
with engine.connect() as conn:
    query = text('''
                    SELECT "SexoConsumidor" as Genero, COUNT(*) as Quantidade, ROUND((COUNT(*) / (SUM(COUNT(*)) OVER() )) * 100) as percentual
                    FROM reclamacoes r
                    GROUP BY "SexoConsumidor"
                    ORDER BY Quantidade DESC''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head(30)
# Out:
#   genero  quantidade  percentual
# 0      F       60217        52.0
# 1      M       54544        47.0
# 2      N        1121         1.0
# 3   None          37         0.0

# %% [markdown]
# #### Tipo de atividade com mais reclamações

# %%
with engine.connect() as conn:
    query = text('''SELECT "DescCNAEPrincipal", COUNT(*) AS quantidade
                    FROM reclamacoes r
                    LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor"
                    GROUP BY "DescCNAEPrincipal"
                    ORDER BY quantidade DESC
                    OFFSET 1
                    LIMIT 20;''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head(10)
# Out:
#                                    DescCNAEPrincipal  quantidade
# 0           BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL       10795
# 1                            TELEFONIA MÓVEL CELULAR        7739
# 2         SERVIÇOS DE TELEFONIA FIXA COMUTADA - STFC        6113
# 3                   DISTRIBUIÇÃO DE ENERGIA ELÉTRICA        4852
# 4  COMÉRCIO VAREJISTA ESPECIALIZADO DE ELETRODOMÉ...        4416
# 5                                    SEGUROS DE VIDA        2635
# 6                       COMÉRCIO VAREJISTA DE MÓVEIS        2506
# 7                                   SEGUROS NÃO-VIDA        2274
# 8                                  CAIXAS ECONÔMICAS        2268
# 9  SOCIEDADES DE CRÉDITO, FINANCIAMENTO E INVESTI...        2154

# %% [markdown]
# #### 5 estados com maior número de reclamações

# %%
with engine.connect() as conn:
    query = text('''SELECT "UF", COUNT(*) AS quantidade from reclamacoes GROUP BY "UF" ORDER BY quantidade DESC LIMIT 5;''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head()
# Out:
#    UF  quantidade
# 0  SP       40999
# 1  GO       17259
# 2  MG        8550
# 3  RN        8125
# 4  MT        7822

# %% [markdown]
# #### Média de reclamações por dia

# %%
with engine.connect() as conn:
    query = text('''SELECT ROUND(AVG(count)) as Media_reclamações FROM (SELECT DATE_PART('day',"DataAbertura") as dia, COUNT(*) FROM reclamacoes GROUP BY dia ORDER BY dia DESC OFFSET 1) as contagem''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
print("Média de reclamações por dia: ",df.values[0][0])
# Out:
# Média de reclamações por dia:  3739.0

# %% [markdown]
# #### Reclamações da Leroy Merlin

# %%
with engine.connect() as conn:
    query = text('''SELECT COUNT(*) FROM reclamacoes r LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor" WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%';''')
    count = pd.read_sql_query(query, con = conn)
    query = text('''SELECT * FROM reclamacoes r
                    LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor"
                    LEFT JOIN problemas p ON r."CodigoProblema" = p."CodigoProblema"
                    LEFT JOIN assuntos a ON r."CodigoAssunto" = a."CodigoAssunto"
                    WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%';''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
print(f'Contagem de registros:', count.values[0][0])
# Out:
# Contagem de registros: 32

# %%
df.head(30)
# Out:
#     AnoCalendario    DataArquivamento        DataAbertura        Regiao  UF  \
# 0            2021 2021-04-21 14:12:54 2021-04-14 10:27:35       Sudeste  RJ
# 1            2021 2021-08-24 15:28:11 2020-12-29 11:26:57       Sudeste  SP
# 2            2017 2017-09-15 12:05:49 2017-08-28 13:36:20       Sudeste  SP
# 3            2017 2017-12-13 18:14:06 2017-11-17 13:31:38  Centro-oeste  MS
# 4            2017 2018-05-22 09:27:40 2018-02-09 16:10:54      Nordeste  RN
# 5            2017 2017-11-01 11:43:09 2017-10-05 07:52:50  Centro-oeste  MS
# 6            2017 2017-12-13 08:52:37 2017-11-16 13:12:15  Centro-oeste  MS
# 7            2017 2017-07-25 14:30:53 2016-02-23 13:22:53       Sudeste  MG
# 8            2017 2017-12-27 14:24:37 2017-10-11 10:29:48       Sudeste  SP
# 9            2017 2017-01-18 14:24:12 2016-10-18 11:19:56       Sudeste  SP
# 10           2018 2018-05-22 09:27:40 2018-02-09 16:10:54      Nordeste  RN
# 11           2018 2018-12-03 14:25:43 2018-08-02 15:09:15       Sudeste  SP
# 12           2018 2018-10-26 11:05:01 2018-08-14 11:33:21       Sudeste  SP
# 13           2018 2018-12-06 13:53:35 2018-09-05 09:44:12       Sudeste  SP
# 14           2018 2018-12-19 14:23:45 2018-11-14 13:51:20      Nordeste  RN
# 15           2018 2018-10-10 09:54:19 2018-08-06 16:08:35       Sudeste  SP
# 16           2018 2018-12-20 12:59:44 2018-09-19 11:30:21       Sudeste  SP
# 17           2018 2018-07-24 10:53:51 2018-05-10 09:18:07       Sudeste  SP
# 18           2018 2018-05-08 10:29:59 2018-02-27 11:50:33       Sudeste  SP
# 19           2019 2019-09-03 13:36:54 2019-04-03 23:00:27       Sudeste  SP
# 20           2019 2019-09-03 09:31:30 2019-04-25 23:00:16       Sudeste  SP
# 21           2019 2019-09-24 13:27:29 2019-05-10 23:00:22       Sudeste  SP
# 22           2019 2019-07-05 14:01:41 2019-02-18 14:48:51      Nordeste  RN
# 23           2019 2019-10-25 11:30:10 2019-10-04 12:48:53       Sudeste  RJ
# 24           2019 2019-09-03 15:49:54 2019-04-16 23:00:12       Sudeste  SP
# 25           2019 2019-09-03 15:49:54 2019-04-16 23:00:12       Sudeste  SP
# 26           2019 2019-09-27 12:24:12 2019-04-04 08:28:03       Sudeste  SP
# 27           2019 2019-09-25 14:59:25 2019-06-24 11:50:12       Sudeste  SP
# 28           2019 2019-12-18 16:19:58 2019-10-16 14:32:30  Centro-oeste  GO
# 29           2020 2020-12-07 16:27:45 2020-01-17 16:53:18  Centro-oeste  GO
#
#    Atendida CodigoAssunto CodigoProblema SexoConsumidor FaixaEtariaConsumidor  \
# 0         S           288           2676              M         Nao Informada
# 1         S           118           2334              M    entre 31 a 40 anos
# 2         S            87           3117              M         Nao Informada
# 3         S            93           2620              M    entre 41 a 50 anos
# 4         S           125           None              F    entre 31 a 40 anos
# 5         S           118           2519              M    entre 61 a 70 anos
# 6         S            93           2620              M    entre 41 a 50 anos
# 7         S           140            105              M    entre 31 a 40 anos
# 8         N            92           2308              F    entre 61 a 70 anos
# 9         N            87           2551              F    entre 21 a 30 anos
# 10        S           125           None              F    entre 31 a 40 anos
# 11        N           118           None              M    entre 21 a 30 anos
# 12        S           118           None              M         Nao Informada
# 13        N           253           None              F    entre 21 a 30 anos
# 14        N           288           None              M    entre 31 a 40 anos
# 15        S           118           None              F         Nao Informada
# 16        N           118           None              F    entre 51 a 60 anos
# 17        N           118           None              F    entre 51 a 60 anos
# 18        S           118           None              F    entre 41 a 50 anos
# 19        N            97           None              M    entre 51 a 60 anos
# 20        N            87           None              F    entre 31 a 40 anos
# 21        N            87           None              F    entre 31 a 40 anos
# 22        N           118           None              M    entre 61 a 70 anos
# 23        N           118           None              M    entre 31 a 40 anos
# 24        N            87           None              M    entre 31 a 40 anos
# 25        S            87           None              M    entre 31 a 40 anos
# 26        N           254           None              F    entre 31 a 40 anos
# 27        N           253           None              F       mais de 70 anos
# 28        S           118           None              F    entre 41 a 50 anos
# 29        S           288           2550              M    entre 21 a 30 anos
#
#     ...  RadicalCNPJ CNAEPrincipal  \
# 0   ...     01438784       4744099
# 1   ...     01438784          None
# 2   ...     01438784       4744099
# 3   ...     01438784          None
# 4   ...     01438784          None
# 5   ...     01438784          None
# 6   ...     01438784          None
# 7   ...     01438784       4744099
# 8   ...     01438784       4744099
# 9   ...     01438784       4744099
# 10  ...     01438784          None
# 11  ...     01438784       4744099
# 12  ...     01438784       4744099
# 13  ...     01438784       4744099
# 14  ...     01438784          None
# 15  ...     01438784       4744099
# 16  ...     01438784       4744099
# 17  ...     01438784       4744099
# 18  ...     01438784       4744099
# 19  ...     01438784       4744099
# 20  ...     01438784       4744099
# 21  ...     01438784       4744099
# 22  ...     01438784          None
# 23  ...     01438784       4744099
# 24  ...     01438784       4744099
# 25  ...     01438784       4744099
# 26  ...     01438784       4744099
# 27  ...     01438784          None
# 28  ...     01438784       4744099
# 29  ...     01438784       4744099
#
#                                     DescCNAEPrincipal  \
# 0   COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 1                                                None
# 2   COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 8   COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 9   COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 10                                               None
# 11  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 12  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 13  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 14                                               None
# 15  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 16  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 17  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 18  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 19  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 20  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 21  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 22                                               None
# 23  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 24  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 25  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 26  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 27                                               None
# 28  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
# 29  COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO ...
#
#                                      RazaoSocialRFB NomeFantasiaRFB  \
# 0                                              None            None
# 1                                              None            None
# 2                                              None            None
# 3                                              None            None
# 4                                              None            None
# 5                                              None            None
# 6                                              None            None
# 7   LEROY MERLIN COMPANHIA BRASILEIRA DE BRICOLAGEM            None
# 8   LEROY MERLIN COMPANHIA BRASILEIRA DE BRICOLAGEM            None
# 9                                              None            None
# 10                                             None            None
# 11                                             None            None
# 12                                             None            None
# 13                                             None            None
# 14                                             None            None
# 15                                             None            None
# 16                                             None            None
# 17                                             None            None
# 18                                             None            None
# 19                                             None            None
# 20                                             None            None
# 21                                             None            None
# 22                                             None            None
# 23                                             None            None
# 24                                             None            None
# 25                                             None            None
# 26                                             None            None
# 27                                             None            None
# 28  LEROY MERLIN COMPANHIA BRASILEIRA DE BRICOLAGEM            None
# 29  LEROY MERLIN COMPANHIA BRASILEIRA DE BRICOLAGEM            None
#
#    CodigoFornecedor CodigoProblema  \
# 0               356           2676
# 1              1929           2334
# 2               356           3117
# 3              6727           2620
# 4              1929           None
# 5              6727           2519
# 6              6727           2620
# 7              7457            105
# 8              8172           2308
# 9               356           2551
# 10             1929           None
# 11              356           None
# 12              356           None
# 13              356           None
# 14             1929           None
# 15              356           None
# 16              356           None
# 17              356           None
# 18              356           None
# 19              356           None
# 20              356           None
# 21              356           None
# 22            16081           None
# 23              356           None
# 24              356           None
# 25              356           None
# 26              356           None
# 27            16998           None
# 28             7457           None
# 29             7457           2550
#
#                                  DescricaoProblema CodigoAssunto  \
# 0         Não entrega/demora na entrega do produto           288
# 1          Garantia (Abrangência, cobertura, etc.)           118
# 2   Desistência de compra (cancelamento de compra)            87
# 3         Não entrega/demora na entrega do produto            93
# 4                                             None           125
# 5                                Produto com vício           118
# 6         Não entrega/demora na entrega do produto            93
# 7                        Peso, volume e quantidade           140
# 8          Garantia (Abrangência, cobertura, etc.)            92
# 9             Produto entregue diferente do pedido            87
# 10                                            None           125
# 11                                            None           118
# 12                                            None           118
# 13                                            None           253
# 14                                            None           288
# 15                                            None           118
# 16                                            None           118
# 17                                            None           118
# 18                                            None           118
# 19                                            None            97
# 20                                            None            87
# 21                                            None            87
# 22                                            None           118
# 23                                            None           118
# 24                                            None            87
# 25                                            None            87
# 26                                            None           254
# 27                                            None           253
# 28                                            None           118
# 29                               Produto com vício           288
#
#                                      DescricaoAssunto
# 0                             Máquinas e Equipamentos
# 1   Material de Acabamento de Construção Pronto (P...
# 2   Material de Construção (areia, cimento, tijolo...
# 3                                  Fogão e Microondas
# 4   Aquecedor / Ventilador / Ar Condicionado / Cir...
# 5   Material de Acabamento de Construção Pronto (P...
# 6                                  Fogão e Microondas
# 7                          Eletroeletrônico Importado
# 8           Máquina de Lavar Roupa / Louça e Secadora
# 9   Material de Construção (areia, cimento, tijolo...
# 10  Aquecedor / Ventilador / Ar Condicionado / Cir...
# 11  Material de Acabamento de Construção Pronto (P...
# 12  Material de Acabamento de Construção Pronto (P...
# 13       Construção / Reforma / Montagem / Acabamento
# 14                            Máquinas e Equipamentos
# 15  Material de Acabamento de Construção Pronto (P...
# 16  Material de Acabamento de Construção Pronto (P...
# 17  Material de Acabamento de Construção Pronto (P...
# 18  Material de Acabamento de Construção Pronto (P...
# 19  Eletroportáteis ( Batedeira, Liqüidificador, E...
# 20  Material de Construção (areia, cimento, tijolo...
# 21  Material de Construção (areia, cimento, tijolo...
# 22  Material de Acabamento de Construção Pronto (P...
# 23  Material de Acabamento de Construção Pronto (P...
# 24  Material de Construção (areia, cimento, tijolo...
# 25  Material de Construção (areia, cimento, tijolo...
# 26                             Serviços de Marcenaria
# 27       Construção / Reforma / Montagem / Acabamento
# 28  Material de Acabamento de Construção Pronto (P...
# 29                            Máquinas e Equipamentos
#
# [30 rows x 24 columns]

# %%
with engine.connect() as conn:
    query = text('''SELECT COUNT(*) FROM reclamacoes r LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor" WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%';''')
    count = pd.read_sql_query(query, con = conn)
    query = text('''SELECT * FROM reclamacoes r
                    LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor"
                    LEFT JOIN problemas p ON r."CodigoProblema" = p."CodigoProblema"
                    LEFT JOIN assuntos a ON r."CodigoAssunto" = a."CodigoAssunto"
                    WHERE "RadicalCNPJ" = '01438784';''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
print(f'Contagem de registros:', count.values[0][0])
# Out:
# Contagem de registros: 32

# %% [markdown]
# #### Reclamações Leroy/ano

# %%
with engine.connect() as conn:
    query = text('''SELECT "AnoCalendario", COUNT(*) FROM reclamacoes r LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor" WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%' GROUP BY "AnoCalendario";''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head()
# Out:
#    AnoCalendario  count
# 0           2017      8
# 1           2018      9
# 2           2019     10
# 3           2020      3
# 4           2021      2

# %% [markdown]
# #### Assuntos e Problemas Reclamações Leroy

# %%
with engine.connect() as conn:
    query = text('''SELECT "DescricaoAssunto", "DescricaoProblema", COUNT(*) as quantidade  FROM reclamacoes r 
                        LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor"
                        LEFT JOIN assuntos a ON r."CodigoAssunto" = a."CodigoAssunto"
                        LEFT JOIN problemas p ON r."CodigoProblema" = p."CodigoProblema"
                        WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%'
                        GROUP BY "DescricaoProblema", a."DescricaoAssunto" 
                        ORDER BY quantidade DESC ;''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head(30)
# Out:
#                                      DescricaoAssunto  \
# 0   Material de Acabamento de Construção Pronto (P...
# 1   Material de Construção (areia, cimento, tijolo...
# 2                                  Fogão e Microondas
# 3   Aquecedor / Ventilador / Ar Condicionado / Cir...
# 4        Construção / Reforma / Montagem / Acabamento
# 5                          Eletroeletrônico Importado
# 6                             Máquinas e Equipamentos
# 7   Material de Acabamento de Construção Pronto (P...
# 8   Televisão / Vídeo Cassete / Filmadora / Video-...
# 9   Material de Construção (areia, cimento, tijolo...
# 10  Eletroportáteis ( Batedeira, Liqüidificador, E...
# 11                            Máquinas e Equipamentos
# 12  Produtos de Decoração ( Cinzeiro, Vasos, Abajur )
# 13                             Serviços de Marcenaria
# 14  Material de Construção (areia, cimento, tijolo...
# 15          Máquina de Lavar Roupa / Louça e Secadora
# 16  Material de Acabamento de Construção Pronto (P...
# 17                            Máquinas e Equipamentos
#
#                                     DescricaoProblema  quantidade
# 0                                                None           9
# 1                                                None           4
# 2            Não entrega/demora na entrega do produto           2
# 3                                                None           2
# 4                                                None           2
# 5                           Peso, volume e quantidade           1
# 6                                   Produto com vício           1
# 7                                   Produto com vício           1
# 8                                   Produto com vício           1
# 9                Produto entregue diferente do pedido           1
# 10                                               None           1
# 11                                               None           1
# 12  Contrato/pedido/orçamento (rescisão, descumpri...           1
# 13                                               None           1
# 14     Desistência de compra (cancelamento de compra)           1
# 15            Garantia (Abrangência, cobertura, etc.)           1
# 16            Garantia (Abrangência, cobertura, etc.)           1
# 17           Não entrega/demora na entrega do produto           1

# %% [markdown]
# #### Assuntos Reclamacoes Leroy

# %%
with engine.connect() as conn:
    query = text('''SELECT "DescricaoAssunto", COUNT(*) as quantidade, ROUND((COUNT(*) / (SUM(COUNT(*)) OVER() )) * 100) as percentual  
                        FROM reclamacoes r 
                        LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor"
                        LEFT JOIN assuntos a ON r."CodigoAssunto" = a."CodigoAssunto"
                        WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%'
                        GROUP BY a."DescricaoAssunto" 
                        ORDER BY quantidade DESC ;''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head(30)
# Out:
#                                      DescricaoAssunto  quantidade  percentual
# 0   Material de Acabamento de Construção Pronto (P...          11        34.0
# 1   Material de Construção (areia, cimento, tijolo...           6        19.0
# 2                             Máquinas e Equipamentos           3         9.0
# 3   Aquecedor / Ventilador / Ar Condicionado / Cir...           2         6.0
# 4        Construção / Reforma / Montagem / Acabamento           2         6.0
# 5                                  Fogão e Microondas           2         6.0
# 6           Máquina de Lavar Roupa / Louça e Secadora           1         3.0
# 7   Eletroportáteis ( Batedeira, Liqüidificador, E...           1         3.0
# 8                          Eletroeletrônico Importado           1         3.0
# 9   Produtos de Decoração ( Cinzeiro, Vasos, Abajur )           1         3.0
# 10                             Serviços de Marcenaria           1         3.0
# 11  Televisão / Vídeo Cassete / Filmadora / Video-...           1         3.0

# %% [markdown]
# #### Problemas reclamações Leroy

# %%
with engine.connect() as conn:
    query = text('''SELECT "DescricaoProblema", COUNT(*) as quantidade  FROM reclamacoes r 
                        LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor"
                        LEFT JOIN problemas p ON r."CodigoProblema" = p."CodigoProblema"
                        WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%'
                        GROUP BY "DescricaoProblema"
                        ORDER BY quantidade DESC ;''')
    df = pd.read_sql_query(query, con = conn)
engine.dispose()
df.head(30)
# Out:
#                                    DescricaoProblema  quantidade
# 0                                               None          20
# 1                                  Produto com vício           3
# 2           Não entrega/demora na entrega do produto           3
# 3            Garantia (Abrangência, cobertura, etc.)           2
# 4                          Peso, volume e quantidade           1
# 5     Desistência de compra (cancelamento de compra)           1
# 6  Contrato/pedido/orçamento (rescisão, descumpri...           1
# 7               Produto entregue diferente do pedido           1

# %% [markdown]
# #### Número de reclamações de empresas da mesma categoria da Leroy

# %%
with engine.connect() as conn:
    query = text('''SELECT "CNAEPrincipal" FROM fornecedores f WHERE "strRazaoSocial" LIKE '%LEROY MERLIN%';''')
    df = pd.read_sql_query(query, con = conn)
    cnae_principal = df.values[0][0]
    query = text(f'''SELECT "strNomeFantasia", COUNT(*) as quantidade 
                    FROM reclamacoes r
                    LEFT JOIN fornecedores f ON r."CodigoFornecedor" = f."CodigoFornecedor"
                    WHERE f."CNAEPrincipal" = '{cnae_principal}'
                    GROUP BY "strNomeFantasia"
                    ORDER BY quantidade DESC;''')
    df = pd.read_sql_query(query, con = conn)
    
engine.dispose()

df.head(10)
# Out:
#                                    strNomeFantasia  quantidade
# 0           MADEIRAMADEIRA COMERCIO ELETRONICO S/A          88
# 1  LEROY MERLIN COMPANHIA BRASILEIRA DE BRICOLAGEM          22
# 2                          M.I. REVESTIMENTOS LTDA          15
# 3                                       CEC.COM.BR          13
# 4                   CASSOL MATERIAIS DE CONSTRUCAO           9
# 5                                     ARMAZÉM PARÁ           8
# 6                                           DICICO           7
# 7                                             SACI           6
# 8                                          CARAJÁS           5
# 9                             CASA LIKE  AMBIENTES           4
